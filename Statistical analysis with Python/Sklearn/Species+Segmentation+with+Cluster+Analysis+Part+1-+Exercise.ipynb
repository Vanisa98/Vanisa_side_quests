# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset is one of the most popular ones for machine learning. You can read a lot about it online and have probably already heard of it: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# We didn't want to use it in the lectures, but believe that it would be very interesting for you to try it out (and maybe read about it on your own).
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.
#
# Start by creating 2 clusters. Then standardize the data and try again. Does it make a difference?
#
# Use the Elbow rule to determine how many clusters are there.

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Set the styles to Seaborn
sns.set()
# Import the KMeans module so we can perform k-means clustering with sklearn
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
data = pd.read_csv('iris_dataset.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Plot the data

# %% [markdown]
# For this exercise, try to cluster the iris flowers by the shape of their sepal.
#
# <i> Use the 'sepal_length' and 'sepal_width' variables.</i>

# %%
sepal = data.iloc[:, :2]
sepal
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# # Clustering (unscaled data)

# %% [markdown]
# Separate the original data into 2 clusters.

# %%
kmeans = KMeans(5)
kmeans.fit(sepal)
# Out:
# KMeans(n_clusters=5)

# %%
clusters = sepal.copy()
clusters['cluster_pred'] = kmeans.fit_predict(sepal)

# %%
plt.scatter(clusters['sepal_length'], clusters['sepal_width'], c=clusters['cluster_pred'], cmap='rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %% [markdown]
# # Standardize the variables

# %% [markdown]
# Import and use the <i> method </i> function from sklearn to standardize the data.

# %%
from sklearn import preprocessing 
sepal_scaled = preprocessing.scale(sepal)
sepal_scaled
# Out:
# array([[-0.90068117,  1.03205722],
#        [-1.14301691, -0.1249576 ],
#        [-1.38535265,  0.33784833],
#        [-1.50652052,  0.10644536],
#        [-1.02184904,  1.26346019],
#        [-0.53717756,  1.95766909],
#        [-1.50652052,  0.80065426],
#        [-1.02184904,  0.80065426],
#        [-1.74885626, -0.35636057],
#        [-1.14301691,  0.10644536],
#        [-0.53717756,  1.49486315],
#        [-1.26418478,  0.80065426],
#        [-1.26418478, -0.1249576 ],
#        [-1.87002413, -0.1249576 ],
#        [-0.05250608,  2.18907205],
#        [-0.17367395,  3.11468391],
#        [-0.53717756,  1.95766909],
#        [-0.90068117,  1.03205722],
#        [-0.17367395,  1.72626612],
#        [-0.90068117,  1.72626612],
#        [-0.53717756,  0.80065426],
#        [-0.90068117,  1.49486315],
#        [-1.50652052,  1.26346019],
#        [-0.90068117,  0.56925129],
#        [-1.26418478,  0.80065426],
#        [-1.02184904, -0.1249576 ],
#        [-1.02184904,  0.80065426],
# ...

# %% [markdown]
# # Clustering (scaled data)

# %%
#kmeans = KMeans(2)
kmeans.fit(sepal_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
data_scaled = sepal.copy()
data_scaled['cluster_pred'] = kmeans.fit_predict(sepal_scaled)
data_scaled
# Out:
#      sepal_length  sepal_width  cluster_pred
# 0             5.1          3.5             0
# 1             4.9          3.0             0
# 2             4.7          3.2             0
# 3             4.6          3.1             0
# 4             5.0          3.6             0
# ..            ...          ...           ...
# 145           6.7          3.0             2
# 146           6.3          2.5             3
# 147           6.5          3.0             2
# 148           6.2          3.4             2
# 149           5.9          3.0             1
#
# [150 rows x 3 columns]

# %%
plt.scatter(data_scaled['sepal_length'], data_scaled['sepal_width'], c=data_scaled['cluster_pred'], cmap='rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
wcss = []

for i in range(1,6):
    kmeans = KMeans(i)
    kmeans.fit(sepal_scaled)
    wcss.append(kmeans.inertia_)

wcss
# Out:
# [300.0,
#  168.3926219836109,
#  103.8069209016144,
#  79.71202301024587,
#  63.299739592712726]

# %% [markdown]
# ### The Elbow Method

# %%
plt.plot(range(1,6),wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# How many clusters are there?
